# %%
# %pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# ...
#   Using cached numpy-2.4.2-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.9 MB 8.7 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/9.9 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.9 MB 8.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.9 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 7.0 MB/s  0:00:01
# Using cached numpy-2.4.2-cp314-cp314-win_amd64.whl (12.4 MB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
# ...

# %%
# %pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matploblib (from versions: none)
# ERROR: No matching distribution found for matploblib

# %%
# %pip install seaborn
# Out:
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.3 MB 9.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.3 MB 9.6 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.3 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 9.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    --------------------------- ------------ 1.6/2.3 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
# ...

# %%
# %pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.9 MB 10.4 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/9.9 MB 10.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 10.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 8.3 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
# ...

# %%
# %pip install -U scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.1 MB 10.2 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 9.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 9.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/37.1 MB ? eta -:--:--
#    - -------------------------------------- 1.0/37.1 MB 5.5 MB/s eta 0:00:07
# ...

# %%
# %pip install -U statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 5.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.6 MB 7.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.6 MB 7.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.6 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 7.5 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
# ...
